# %% [markdown]
# ## Class and Object

# %%
class Parrot:

    # class attribute
    species = "bird" #클래스 어트리뷰트

    # instance attribute
    def __init__(self, name, age):
        self.name = name
        self.age = age #인스턴스 어트리뷰트(self 있는거.)
        
        #멤버 변수 3개됨
        #type의 이름이 나오는 것은 인스턴스
        #type  쳤을때 이름이 type나오면 class
        
# instantiate the Parrot class
blu = Parrot("Blu", 10)
woo = Parrot("Woo", 15)

# access the class attributes
print("Blu is a {}".format(blu.__class__.species))
print("Woo is also a {}".format(woo.__class__.species))

# access the instance attributes
print("{} is {} years old".format( blu.name, blu.age))
print("{} is {} years old".format( woo.name, woo.age))
# Out:
# Blu is a bird
# Woo is also a bird
# Blu is 10 years old
# Woo is 15 years old

# %%
vars(blu)
# Out:
# {'name': 'Blu', 'age': 10}

# %%
blu.__dict__
# Out:
# {'name': 'Blu', 'age': 10}

# %%
blu.species = 'bird2'

# %%
blu.__dict__
# Out:
# {'name': 'Blu', 'age': 10, 'species': 'bird2'}

# %%
dir(woo)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name',
#  'species']

# %%
woo.species #static하고 비슷 java에서
# Out:
# 'bird'

# %%
blu.species #인스턴스 어트리뷰트를 덮어쓴 것.
# Out:
# 'bird2'

# %%
Parrot.species #클래스 어트리뷰트 사용법
# Out:
# 'bird'

# %%
#인스턴스 어트리뷰트는 인스턴스 되어야지만 사용가능.

# %%
woo.__dict__
# Out:
# {'name': 'Woo', 'age': 15}

# %%
# access the class attributes
print("Blu is a {}".format(blu.__class__.species))
print("Woo is also a {}".format(woo.__class__.species))

# access the instance attributes
print("{} is {} years old".format( blu.name, blu.age))
print("{} is {} years old".format( woo.name, woo.age))
# Out:
# Blu is a bird
# Woo is also a bird
# Blu is 10 years old
# Woo is 15 years old

# %%
문근영 = Parrot('문근영',30)

# %%
vars(문근영)
# Out:
# {'name': '문근영', 'age': 30}

# %%
문근영.species
# Out:
# 'bird'

# %%
문근영.species = 'bird2' #인스턴스 어트리뷰트

# %%
문근영.species #class어트리뷰느는 아직있지만 우선순위가 밀림
# Out:
# 'bird2'

# %%
#class를 우선순위로 하려면 
문근영.__class__.species
# Out:
# 'bird'

# %%
문근영.__class__ #현재 작업하고 있는 공간.
# Out:
# __main__.Parrot

# %% [markdown]
# ## Methods

# %%
class Parrot:
    
    # instance attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # instance method
    def sing(self, song):
        return "{} sings {}".format(self.name, song)

    def dance(self):
        return "{} is now dancing".format(self.name)
    
    #class.하면 인스턴스 써야하고
    #인스턴스(dance).하면 아무것도 안써야한다.
    #뮤터블은 자기자신이 바뀌는게 뮤터블 
    
    

# instantiate the object
blu = Parrot("Blu", 10)

# call our instance methods
print(blu.sing("'Happy'"))
print(blu.dance())
# Out:
# Blu sings 'Happy'
# Blu is now dancing

# %%
class Parrot:
    
    # instance attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # instance method
    def sing(self, song):
        return "{} sings {}".format(self.name, song)

    def dance(self):
        return "{} is now dancing".format(self.name)
    @classmethod
    def dance2(cls): #두번째꺼는 관례상 cls
        return "is now dancing"

Parrot.sing(문근영,'노래')
#문근영.sing('노래')
# Out:
# '문근영 sings 노래'

# %%
a=Parrot('sun',42)

# %%
Parrot.dance(a)
a.dance()
# Out:
# 'sun is now dancing'

# %%
Parrot.dance2()
# Out:
# 'is now dancing'

# %%
a.__class__.dance2()
# Out:
# 'is now dancing'

# %%
class Parrot:
    
    # instance attributes
    def __init__(self2, name, age):
        self2.name = name
        self2.age = age
    
    # instance method
    def sing(self2, song):
        return "{} sings {}".format(self2.name, song)

    def dance(self2):
        return "{} is now dancing".format(self2.name)

# instantiate the object
blu = Parrot("Blu", 10)

# call our instance methods
print(blu.sing("'Happy'"))
print(blu.dance())

#self는 키워드가 아니므로 다른 아무 글자나 넣어도 실행된다 똑같이 
#메소트의 첫번 째 인자는 자기자신을 가르키는 애다. 관례상 self라고 함.
# Out:
# Blu sings 'Happy'
# Blu is now dancing

# %%
Parrot.sing(문근영,'노래')
문근영.sing('노래') #같은 말이다.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-5e26fe4ffe99> in <module>()
#       1 Parrot.sing(문근영,'노래')
# ----> 2 문근영.sing('노래') #같은 말이다.
#
# AttributeError: 'Parrot' object has no attribute 'sing'

# %% [markdown]
# ## Inheritance

# %%
# parent class
class Bird:
    
    def __init__(self):
        print("Bird is ready")

    def whoisThis(self):
        print("Bird")

    def swim(self):
        print("Swim faster")

        #attribute : 0개
        #상속 : pengui(bird) : 펭귄클래스는 버드 클래스를 상속받는다. 
        
# child class
class Penguin(Bird):

    def __init__(self):
        # call super() function
        super().__init__()
        print("Penguin is ready")

    def whoisThis(self):
        print("Penguin")

    def run(self):
        print("Run faster")

peggy = Penguin()
peggy.whoisThis()
peggy.swim()
peggy.run()
# Out:
# Bird is ready
# Penguin is ready
# Penguin
# Swim faster
# Run faster

# %%
# child class
class Penguin(Bird):
    pass

   # def __init__(self):
        # call super() function
    #    super().__init__()
     #   print("Penguin is ready")

   # def whoisThis(self):
    #    print("Penguin")

   # def run(self):
    #    print("Run faster")

# %%
dir(Penguin)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'swim',
#  'whoisThis']

# %%
class Penguin(Bird):
    def swim(self):
              print("i cant swim")
    def run(self):
            print("Run faster") #상속의 의미 오버라이딩

# %%
peggy = Penguin()
peggy.whoisThis()
peggy.swim()
# Out:
# Bird is ready
# Bird
# i cant swim

# %%
 안 넣어보고 
        #다중상속이 있을 때 내가 어떤 부모를 상속받을지 딱 찍어서 알려줌. 
        #기본적인 순서 왼쪽에 있는 애부터 class penguin(bird,어쩌고,...):다중상속
        print("Penguin is ready")

   # def whoisThis(self):
    #    print("Penguin")

    def run(self):
        print("Run faster")

# %%
peggy = Penguin()
peggy.whoisThis()
peggy.swim()
# Out:
# Bird is ready
# Penguin is ready
# Bird
# Swim faster

# %% [markdown]
# ## Encapsulation

# %%
class Computer:

    def __init__(self):
        self.__maxprice = 900

    def sell(self):
        print("Selling Price: {}".format(self.__maxprice))

    def setMaxPrice(self, price):
        self.__maxprice = price

c = Computer()
c.sell()

# change the price
c.__maxprice = 1000
c.sell()

# using setter function
c.setMaxPrice(1000)
c.sell()
# Out:
# Selling Price: 900
# Selling Price: 900
# Selling Price: 1000

# %%
dir()
# Out:
# ['Bird',
#  'Computer',
#  'In',
#  'Out',
#  'Parrot',
#  'Penguin',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_17',
#  '_18',
#  '_2',
#  '_21',
#  '_22',
#  '_24',
#  '_25',
#  '_26',
#  '_29',
#  '_3',
#  '_34',
#  '_36',
#  '_39',
#  '_4',
#  '_40',
#  '_41',
#  '_43',
#  '_44',
#  '_46',
#  '_47',
#  '_49',
#  '_50',
#  '_51',
#  '_55',
#  '_6',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class Parrot:\n\n    # class attribute\n    species = "bird"\n\n    # instance attribute\n    def __init__(self, name, age):\n        self.name = name\n        self.age = age\n\n        #멤버 변수 3개됨\n        \n# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)\n\n# access the class attributes\nprint("Blu is a {}".format(blu.__class__.species))\nprint("Woo is also a {}".format(woo.__class__.species))\n\n# access the instance attributes\nprint("{} is {} years old".format( blu.name, blu.age))\nprint("{} is {} years old".format( woo.name, woo.age))',
#   'vars(blu)',
#   'vars(blu)',
#   'blu.__dict__',
#   "blu.species = 'bird2'",
#   'blu.__dict__',
#   'dir(woo)',
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class Parrot:\n\n    # class attribute\n    species = "bird"\n\n    # instance attribute\n    def __init__(self, name, age):\n        self.name = name\n        self.age = age\n\n        #멤버 변수 3개됨\n        \n# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)\n\n# access the class attributes\nprint("Blu is a {}".format(blu.__class__.species))\nprint("Woo is also a {}".format(woo.__class__.species))\n\n# access the instance attributes\nprint("{} is {} years old".format( blu.name, blu.age))\nprint("{} is {} years old".format( woo.name, woo.age))',
#   'vars(blu)',
#   'vars(blu)',
#   'blu.__dict__',
#   "blu.species = 'bird2'",
#   'blu.__dict__',
#   'dir(woo)',
# ...

# %% [markdown]
# ## Polymorphism

# %%
class Parrot:

    def fly(self):
        print("Parrot can fly")
    
    def swim(self):
        print("Parrot can't swim")

class Penguin:

    def fly(self):
        print("Penguin can't fly")
    
    def swim(self):
        print("Penguin can swim")

# common interface
def flying_test(bird):
    bird.fly() #파이썬의 특징 : 상속안받아도 된다.

#instantiate objects
blu = Parrot()
peggy = Penguin()

# passing the object
flying_test(blu)
flying_test(peggy)
# Out:
# Parrot can fly
# Penguin can't fly

# %%
class Polygon:
    def __init__(self, no_of_sides):
        self.n = no_of_sides #인스턴스 어트리뷰트
        self.sides = [0 for i in range(no_of_sides)] #인스턴스 어트리뷰트

    def inputSides(self):
        self.sides = [float(input("Enter side "+str(i+1)+" : ")) for i in range(self.n)]
        #아까 side랑 같은거 덮어씀. 
    def dispSides(self):
        for i in range(self.n):
            print("Side",i+1,"is",self.sides[i]) #i는 어트리뷰트 아님.

# %%
xy = Polygon(5)
yz =Polygon(3)

# %%
xy.sides
# Out:
# [0, 0, 0, 0, 0]

# %%
xy.dispSides()
# Out:
# Side 1 is 0
# Side 2 is 0
# Side 3 is 0
# Side 4 is 0
# Side 5 is 0

# %%
dir(Polygon)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'dispSides',
#  'inputSides']

# %%
a = (x for x in range(11))

# %%
next(a)# a.__next__()랑 같음.
# Out:
# 1

# %%
class Triangle(Polygon): #상속을 받았다. 부모가 가진 속성을 없앨수는 없다. 
    def __init__(self): #인스턴스 메소드 
        Polygon.__init__(self,3) # super().__init__(3)
    #부모이름을 꼭집어서 써줬다. 슈퍼대신 쓸 수 있다.
    def findArea(self): #경우에 따라 다르지만 보통 안넣는다. 
        a, b, c = self.sides
        # calculate the semi-perimeter
        s = (a + b + c) / 2
        area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
        print('The area of the triangle is %0.2f' %area)

# %%
# Output: True
print(issubclass(list,object))

# Output: True
print(isinstance(5.5,object))

# Output: True
print(isinstance("Hello",object))
# Out:
# True
# True
# True

# %%
#다중상속
class X: pass
class Y: pass
class Z: pass

class A(X,Y): pass #우선권은 앞에 있는애 
class B(Y,Z): pass

class M(B,A,Z): pass 

# Output:
# [<class '__main__.M'>, <class '__main__.B'>,
# <class '__main__.A'>, <class '__main__.X'>,
# <class '__main__.Y'>, <class '__main__.Z'>,
# <class 'object'>]

print(M.mro()) #다중상속에서 순서를 알려준다.
# Out:
# [<class '__main__.M'>, <class '__main__.B'>, <class '__main__.A'>, <class '__main__.X'>, <class '__main__.Y'>, <class '__main__.Z'>, <class 'object'>]

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)
    
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)
    
    def __lt__(self,other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag < other_mag

# %%
class B : 
    def __str__(self):
        return 'aaa'
    def __repr__(self):
        return 'bbb'

# %%
abc = B()

# %%
abc# 스페셜 메소드로 오버라이딩 (재정의)
# Out:
# bbb

# %%
print(abc)
# Out:
# aaa

# %%
class Myint(int):
    def __add__(self,other):
        super().__add__()

# %%
a = Myint(3)

# %%
a
# Out:
# 3

# %%
b = Myint(4)

# %%
b
# Out:
# 4

# %%
class Myint(int):
    def __add__(self,other):
        super().__add__(other)

# %%
print(a+b) #연산자는 오버로딩
# Out:
# None

# %%
class Myint(int):
    def __add__(self,other):
        super().__add__(other)#srt 프린트할 때 , repr변수명 선언
    def __str__(self):
        return
    def __repr__(self):
        return

# %%
class Myint(int):
    def __init__(self,num):
        self.num = num
    def __add__(self,other):
        print('문근영')
        return self.num+other+3
        #연산자 오버로딩 
    def __repr__(self):
         print('알알려')

# %%
a = Myint(3)

# %%
b = Myint(4)

# %%
a+b
# Out:
# 문근영
# 10

# %%
3 .__str__() #str로 형변환 해주는 애 (int에 있는 str)
# Out:
# '3'

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
class Myint(int):
    def __init__(self,num):
        self.num = num
    def __add__(self,other):
        print('문근영')
        return self.num+other+3
        #연산자 오버로딩 
    def __str_(self,other):
        print('aaa')
        return str(self.num+other+3)
    def __radd__(self,otehr):
        return self.num+other +1 # radd

# %%
a = Myint(3)

# %%
b = Myint(4)

# %% [raw]
# (a+b).__str__()

# %%
Myint(2)+Myint(1)
# Out:
# 문근영
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-cd78d67fa3e1> in <module>()
# ----> 1 Myint(2)+Myint(1)
#
# <ipython-input-153-fb9c29791f98> in __add__(self, other)
#       4     def __add__(self,other):
#       5         print('문근영')
# ----> 6         return self.num+other+3
#       7         #연산자 오버로딩
#       8     def __str_(self,other):
#
# <ipython-input-153-fb9c29791f98> in __radd__(self, otehr)
#      10         return str(self.num+other+3)
#      11     def __radd__(self,otehr):
# ---> 12         return self.num+other +1
#
# NameError: name 'other' is not defined

# %%
#빼기는 rsub

# %%
#나만의 객체 만들 때,연산자 오버로딩
class AA:
    def __init__(self,num):
        self.num = num
    def __add__(self,other):
