# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('data/nobel_winners_dirty.json')

# %%
df.describe(include='all')
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
# mean       NaN                     NaN            NaN              NaN
# std        NaN                     NaN            NaN              NaN
# min        NaN                     NaN            NaN              NaN
# 25%        NaN                     NaN            NaN              NaN
# 50%        NaN                     NaN            NaN              NaN
# 75%        NaN                     NaN            NaN              NaN
# max        NaN                     NaN            NaN              NaN
#
#        date_of_death gender                                         link  \
# ...

# %%
df.describe(include=['object'])
### object: statistics for string Data
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                 name place_of_birth place_of_death  \
# count           1052           1044           1044
# unique           998            735            410
# top     John Bardeen
# freq               2             29            409
#
# ...

# %%
df.columns
# Out:
# Index(['born_in', 'category', 'country', 'date_of_birth', 'date_of_death',
#        'gender', 'link', 'name', 'place_of_birth', 'place_of_death', 'text',
#        'year'],
#       dtype='object')

# %%
df.columns[1]
### columns : index type: sequence
# Out:
# 'category'

# %%
len(df[df.category =='Chemistry'].country.unique())
### unique: array(set(series))
# Out:
# 25

# %%
df.shape
# Out:
# (1052, 12)

# %%
df_2 = df.set_index('name') ### slicing 이 편함, 또는 time series를 index로 놓고 시계열 분석
df_2.head(2)
# Out:
#                                born_in                category    country  \
# name
# César Milstein                          Physiology or Medicine  Argentina
# Ivo Andric *    Bosnia and Herzegovina              Literature
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# Ivo Andric *    9 October 1892  13 March 1975   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *             http://en.wikipedia.org/wiki/Ivo_Andric
#
#                                                    place_of_birth  \
# name
# César Milstein                          Bahía Blanca ,  Argentina
# Ivo Andric *    Dolac (village near Travnik), Austria-Hungary ...
#
#                                                    place_of_death  \
# name
# César Milstein                                Cambridge , England
# ...

# %%
bi_col = df.born_in
type(bi_col)
# Out:
# pandas.core.series.Series

# %%
df_2.iloc[0]
# Out:
# born_in
# category                                    Physiology or Medicine
# country                                                  Argentina
# date_of_birth                                       8 October 1927
# date_of_death                                        24 March 2002
# gender                                                        male
# link              http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# place_of_birth                           Bahía Blanca ,  Argentina
# place_of_death                                 Cambridge , England
# text                 César Milstein , Physiology or Medicine, 1984
# year                                                          1984
# Name: César Milstein, dtype: object

# %%
df_2.loc['César Milstein']
# Out:
#                born_in                category         country  \
# name
# César Milstein          Physiology or Medicine       Argentina
# César Milstein          Physiology or Medicine  United Kingdom
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# César Milstein  8 October 1927  24 March 2002   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
#
#                            place_of_birth       place_of_death  \
# name
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
#
#                                                              text  year
# name
# César Milstein      César Milstein , Physiology or Medicine, 1984  1984
# ...

# %%
df[df.year>2000]
# Out:
#            born_in                category        country      date_of_birth  \
# 13                                 Physics        Belgium    6 November 1932
# 32                               Economics         Cyprus         1948-02-20
# 66                                   Peace          Ghana       8 April 1938
# 87           Italy                 Physics                   October 6, 1931
# 88           Italy  Physiology or Medicine                    6 October 1937
# 93                               Economics         Israel      March 5, 1934
# 94                               Chemistry         Israel  December 31, 1937
# 95                               Chemistry         Israel    October 1, 1947
# 96                               Economics         Israel       June 8, 1930
# 97                                 Physics    Netherlands     1 October 1958
# 103     Luxembourg  Physiology or Medicine                     2 August 1941
# ...

# %%
df.born_in.apply(len)
## 함수형 패러다임: 각 row의 함수 계산, 인수: 함수 이름
## apply: dataFrame, series 둘 다 사용 가능
# Out:
# 0        0
# 1       22
# 2       22
# 3        0
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       7
# 15       7
# 16       7
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27      14
# 28      14
# 29      14
#         ..
# 1022     0
# 1023     7
# 1024     7
# 1025     0
# 1026     0
# 1027     7
# 1028     0
# 1029     0
# 1030     7
# 1031     7
# 1032     0
# 1033     0
# 1034     7
# 1035     9
# 1036     0
# 1037     0
# 1038     0
# 1039     9
# 1040     0
# 1041     9
# 1042     0
# 1043     0
# 1044     0
# 1045     0
# 1046     9
# 1047     0
# 1048     0
# 1049     0
# 1050     0
# 1051     0
# Name: born_in, Length: 1052, dtype: int64

# %%
df.born_in.map(len)
## map 은 series만 가능
# Out:
# 0        0
# 1       22
# 2       22
# 3        0
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       7
# 15       7
# 16       7
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27      14
# 28      14
# 29      14
#         ..
# 1022     0
# 1023     7
# 1024     7
# 1025     0
# 1026     0
# 1027     7
# 1028     0
# 1029     0
# 1030     7
# 1031     7
# 1032     0
# 1033     0
# 1034     7
# 1035     9
# 1036     0
# 1037     0
# 1038     0
# 1039     9
# 1040     0
# 1041     9
# 1042     0
# 1043     0
# 1044     0
# 1045     0
# 1046     9
# 1047     0
# 1048     0
# 1049     0
# 1050     0
# 1051     0
# Name: born_in, Length: 1052, dtype: int64

# %%
def unknown(x):
    if not len(x): # 0이면
        return 'unknown'
    else:
        return x
df.born_in = df.born_in.map(unknown)

# %%
df['born_in']
# Out:
# 0                      unknown
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                      unknown
# 4                      unknown
# 5                      unknown
# 6                      unknown
# 7                      unknown
# 8                      unknown
# 9                      unknown
# 10                     unknown
# 11                     unknown
# 12                     unknown
# 13                     unknown
# 14                     Belarus
# 15                     Belarus
# 16                     Belarus
# 17                     unknown
# 18                     unknown
# 19                     unknown
# 20                     unknown
# 21                     unknown
# 22                     unknown
# 23                     unknown
# 24                     unknown
# 25                     unknown
# 26                     unknown
# 27              Czech Republic
# 28              Czech Republic
# 29              Czech Republic
# ...

# %%
df.born_in.replace('unknown',np.nan, inplace = True)
## series만 바꾸기

# %%
df.born_in
# Out:
# 0                          NaN
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                     Belarus
# 15                     Belarus
# 16                     Belarus
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27              Czech Republic
# 28              Czech Republic
# 29              Czech Republic
# ...

# %%
df.replace('',np.nan,inplace = True)
## dataFrame 전체 바꾸기
df.place_of_birth.head()
# Out:
# 0                            Bahía Blanca ,  Argentina
# 1    Dolac (village near Travnik), Austria-Hungary ...
# 2    Sarajevo ,  Bosnia and Herzegovina , then part...
# 3                                                 None
# 4               Ostend ,  Netherlands  (now  Belgium )
# Name: place_of_birth, dtype: object

# %%
df[df.name.str.contains('\*')].name
# Out:
# 1                        Ivo Andric *
# 2                   Vladimir Prelog *
# 14                    Simon Kuznets *
# 15                   Menachem Begin *
# 16                     Shimon Peres *
# 27               Bertha von Suttner *
# 28                       Gerty Cori *
# 29              Carl Ferdinand Cori *
# 50                  Henry Kissinger *
# 51                     Arno Penzias *
# 53              Georges J.F. Köhler *
# 58                 Jack Steinberger *
# 63                  Hans G. Dehmelt *
# 82                  Renato Dulbecco *
# 87                Riccardo Giacconi *
# 88                   Mario Capecchi *
# 101     Mario José Molina Henríquez *
# 102                Gabriel Lippmann *
# 103               Jules A. Hoffmann *
# 104                  Andrew Schally *
# 105                  Czesław Miłosz *
# 106                      Aaron Klug *
# 109                 Wilhelm Ostwald *
# 115                    Severo Ochoa *
# 120                Allan M. Cormack *
# ...

# %%
None == None
# Out:
# True

# %%
np.nan == np.nan
## not available (수치 해석에 사용할 수 없는 값)
# Out:
# False

# %%
df.born_in.isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %%
df.born_in.isna()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %%
 df[df.born_in.isnull()]
# Out:
#      born_in                category         country      date_of_birth  \
# 0        NaN  Physiology or Medicine       Argentina     8 October 1927
# 3        NaN                   Peace         Belgium               None
# 4        NaN                   Peace         Belgium       26 July 1829
# 5        NaN              Literature         Belgium     29 August 1862
# 6        NaN                   Peace         Belgium      22 April 1854
# 7        NaN  Physiology or Medicine         Belgium       13 June 1870
# 8        NaN  Physiology or Medicine         Belgium      28 March 1892
# 9        NaN                   Peace         Belgium         1910-02-10
# 10       NaN  Physiology or Medicine         Belgium     24 August 1899
# 11       NaN  Physiology or Medicine         Belgium     2 October 1917
# 12       NaN               Chemistry         Belgium    25 January 1917
# 13       NaN                 Physics         Belgium    6 November 1932
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [born_in, category, country, date_of_birth, date_of_death, gender, link, name, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df = df.drop('born_in',axis = 1)

# %%
df[df.duplicated('name')].name
# Out:
# 131                  AaronKlug
# 134              CésarMilstein
# 309             LinusC.Pauling
# 326                JohnBardeen
# 366            BarujBenacerraf
# 373           FrancoModigliani
# 376        RitaLevi-Montalcini
# 405                RonaldCoase
# 457             DanielKahneman
# 476               RobertAumann
# 580            FrederickSanger
# 586              SydneyBrenner
# 598              MichaelLevitt
# 622                 FelixBloch
# 630            EdmondH.Fischer
# 672            WilhelmOstwald*
# 684            WassilyLeontief
# 688             MenachemBegin*
# 709      MarieSkłodowska-Curie
# 712             AndrewSchally*
# 714             CzesławMiłosz*
# 715             RoaldHoffmann*
# 717            GeorgesCharpak*
# 718               ShimonPeres*
# 721              LeonidHurwicz
# 731                LarsOnsager
# 734                IvarGiaever
# 773              YoichiroNambu
# 776             OsamuShimomura
# 778             Ei-ichiNegishi
# ...

# %%
all_dups = df[df.duplicated('name')\
              | df.duplicated('name', keep ='last')]
## keep: 남길 데이터
all_dups.count()
# Out:
# category          106
# country            92
# date_of_birth     106
# date_of_death      56
# gender            104
# link              108
# name              108
# place_of_birth    106
# place_of_death     54
# text              108
# year              108
# dtype: int64

# %%
df.drop_duplicates('name')
# Out:
#                     category    country      date_of_birth  \
# 0     Physiology or Medicine  Argentina     8 October 1927
# 1                 Literature        NaN     9 October 1892
# 2                  Chemistry        NaN      July 23, 1906
# 3                      Peace    Belgium               None
# 4                      Peace    Belgium       26 July 1829
# 5                 Literature    Belgium     29 August 1862
# 6                      Peace    Belgium      22 April 1854
# 7     Physiology or Medicine    Belgium       13 June 1870
# 8     Physiology or Medicine    Belgium      28 March 1892
# 9                      Peace    Belgium         1910-02-10
# 10    Physiology or Medicine    Belgium     24 August 1899
# 11    Physiology or Medicine    Belgium     2 October 1917
# 12                 Chemistry    Belgium    25 January 1917
# 13                   Physics    Belgium    6 November 1932
# 14                 Economics        NaN     April 30, 1901
# ...

# %%
data = pd.read_csv('E:/Workspace/Bigdata_Edu/1. Lecture Note/16_2. pandas_2_180726/pew.txt',
                   sep='\t')

# %%
data[data.religion == 'Buddhist']
# Out:
#    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  $75-100k  \
# 2  Buddhist     27       21       30       34       33       58        62
#
#    $100-150k  >150k  Don't know/refused
# 2         39     53                  54

# %%
data[data.religion == 'Buddhist'].mean(axis=1)
# Out:
# 2    41.1
# dtype: float64

# %%
melt_data = data.melt('religion')
melt_data.head(10)
# Out:
#                   religion variable  value
# 0                 Agnostic    <$10k     27
# 1                  Atheist    <$10k     12
# 2                 Buddhist    <$10k     27
# 3                 Catholic    <$10k    418
# 4       Don’t know/refused    <$10k     15
# 5         Evangelical Prot    <$10k    575
# 6                    Hindu    <$10k      1
# 7  Historically Black Prot    <$10k    228
# 8        Jehovah's Witness    <$10k     20
# 9                   Jewish    <$10k     19

# %%
melt_data.groupby('religion').mean()
# Out:
#                          value
# religion
# Agnostic                  82.6
# Atheist                   51.5
# Buddhist                  41.1
# Catholic                 805.4
# Don’t know/refused        27.2
# Evangelical Prot         947.2
# Hindu                     25.7
# Historically Black Prot  199.5
# Jehovah's Witness         21.5
# Jewish                    68.2
# Mainline Prot            747.0
# Mormon                    58.1
# Muslim                    11.6
# Orthodox                  36.3
# Other Christian           12.9
# Other Faiths              44.9
# Other World Religions      4.2
# Unaffiliated             370.7

# %%
melt_data.groupby('religion').min()
# Out:
#                         variable  value
# religion
# Agnostic                 $10-20k     27
# Atheist                  $10-20k     12
# Buddhist                 $10-20k     21
# Catholic                 $10-20k    418
# Don’t know/refused       $10-20k     10
# Evangelical Prot         $10-20k    414
# Hindu                    $10-20k      1
# Historically Black Prot  $10-20k     78
# Jehovah's Witness        $10-20k      6
# Jewish                   $10-20k     19
# Mainline Prot            $10-20k    289
# Mormon                   $10-20k     29
# Muslim                   $10-20k      6
# Orthodox                 $10-20k     13
# Other Christian          $10-20k      7
# Other Faiths             $10-20k     20
# Other World Religions    $10-20k      2
# Unaffiliated             $10-20k    217

# %%
data2 = pd.read_csv('E:/Workspace/Bigdata_Edu/1. Lecture Note/16_2. pandas_2_180726/tb.csv')

# %%
melt_data2 = data2.melt(['iso2','year'])

# %%
melt_data2.dropna(inplace=True)

# %%
melt_data2.groupby('year').sum()
# Out:
#           value
# year
# 2005   109408.0
# 2006    81921.0
# 2007   122571.0
# 2008  1421737.0

# %%
data3 = pd.read_csv('E:/Workspace/Bigdata_Edu/1. Lecture Note/16_2. pandas_2_180726/weather.txt',
                   sep = '\t')

# %%
data3 = data3.melt(['id','year','element','month']).dropna()

# %%
del data3['id']

# %%
data3.reset_index(inplace=True)

# %%
data3 = data3[['year','month','element','variable','value']]

# %%
data3.sort_values(['year','month'])
# Out:
#     year  month element variable  value
# 62  2010      1    TMAX      d30  278.0
# 63  2010      1    TMIN      d30  145.0
# 2   2010      2    TMAX       d2  273.0
# 3   2010      2    TMIN       d2  144.0
# 6   2010      2    TMAX       d3  241.0
# 7   2010      2    TMIN       d3  144.0
# 28  2010      2    TMAX      d11  297.0
# 29  2010      2    TMIN      d11  134.0
# 42  2010      2    TMAX      d23  299.0
# 43  2010      2    TMIN      d23  107.0
# 12  2010      3    TMAX       d5  321.0
# 13  2010      3    TMIN       d5  142.0
# 26  2010      3    TMAX      d10  345.0
# 27  2010      3    TMIN      d10  168.0
# 38  2010      3    TMAX      d16  311.0
# 39  2010      3    TMIN      d16  176.0
# 50  2010      4    TMAX      d27  363.0
# 51  2010      4    TMIN      d27  167.0
# 52  2010      5    TMAX      d27  332.0
# 53  2010      5    TMIN      d27  182.0
# 40  2010      6    TMAX      d17  280.0
# 41  2010      6    TMIN      d17  175.0
# ...

# %%
data3.element = data3.element.str.replace('T','')

# %%
data3[data3.element=='MIN'].groupby('month').mean()
# Out:
#        year       value
# month
# 1      2010  145.000000
# 2      2010  132.250000
# 3      2010  162.000000
# 4      2010  167.000000
# 5      2010  182.000000
# 6      2010  177.500000
# 7      2010  170.000000
# 8      2010  158.428571
# 10     2010  130.800000
# 11     2010  125.000000
# 12     2010  121.500000
