# %%
import pandas as pd
pd.__version__
# Out:
# '0.23.0'

# %%
df = pd.read_csv('data-netflix.csv')

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.describe() # R의 summary와 비슷
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %%
df.sample() # 무작위 추출
# Out:
#                                  rating  \
# title
# The Mr. Peabody and Sherman Show  TV-Y7
#
#                                                              ratingLevel  \
# title
# The Mr. Peabody and Sherman Show  Suitable for children ages 7 and older
#
#                                   ratingDescription  release year  \
# title
# The Mr. Peabody and Sherman Show                 41          2017
#
#                                   user rating score  user rating size
# title
# The Mr. Peabody and Sherman Show                NaN                82

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header = None)
# read로 url 읽어올 수 있음

# %%
df.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### DataFrame
# #### 행과 열머리는 Index
# #### Index 별 항목 모음: Series

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df = pd.read_csv('data-netflix.csv', header = 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 7 columns):
# Lucky Number Slevin                                   998 non-null object
# R                                                     998 non-null object
# strong violence, sexual content and adult language    939 non-null object
# 100                                                   998 non-null int64
# 2006                                                  998 non-null int64
# NA                                                    604 non-null float64
# 82                                                    998 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.7+ KB

# %%
df = pd.read_csv('data-netflix.csv', index_col = 'title')
df.head()
# Out:
#                       rating  \
# title
# White Chicks           PG-13
# Lucky Number Slevin        R
# Grey's Anatomy         TV-14
# Prison Break           TV-14
# How I Met Your Mother  TV-PG
#
#                                                              ratingLevel  \
# title
# White Chicks           crude and sexual humor, language and some drug...
# Lucky Number Slevin    strong violence, sexual content and adult lang...
# Grey's Anatomy         Parents strongly cautioned. May be unsuitable ...
# Prison Break           Parents strongly cautioned. May be unsuitable ...
# How I Met Your Mother  Parental guidance suggested. May not be suitab...
#
#                        ratingDescription  release year  user rating score  \
# title
# White Chicks                          80          2004               82.0
# Lucky Number Slevin                  100          2006                NaN
# Grey's Anatomy                        90          2016               98.0
# ...

# %% [markdown]
# usecols: 사용 Data를 처음부터 제한: 지식 기반 필터링

# %%
df = pd.read_csv('data-netflix.csv', usecols=['title','rating','release year'])
df.head()
# Out:
#                    title rating  release year
# 0           White Chicks  PG-13          2004
# 1    Lucky Number Slevin      R          2006
# 2         Grey's Anatomy  TV-14          2016
# 3           Prison Break  TV-14          2008
# 4  How I Met Your Mother  TV-PG          2014

# %% [markdown]
#  err 처리

# %%
df = pd.read_csv('data-netflix.csv', na_values=[''])
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df = pd.read_csv('data-netflix.csv', skip_blank_lines=False)
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df = pd.read_csv('data-netflix.csv', skiprows=[1,3],)
df.head()
# Out:
#                    title rating  \
# 0    Lucky Number Slevin      R
# 1           Prison Break  TV-14
# 2  How I Met Your Mother  TV-PG
# 3           Supernatural  TV-14
# 4           Breaking Bad  TV-MA
#
#                                          ratingLevel  ratingDescription  \
# 0  strong violence, sexual content and adult lang...                100
# 1  Parents strongly cautioned. May be unsuitable ...                 90
# 2  Parental guidance suggested. May not be suitab...                 70
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  For mature audiences.  May not be suitable for...                110
#
#    release year  user rating score  user rating size
# 0          2006                NaN                82
# 1          2008               98.0                80
# 2          2014               94.0                80
# 3          2016               95.0                80
# 4          2013               97.0                80

# %%
df.tail(2)
# Out:
#                title rating             ratingLevel  ratingDescription  \
# 996      Beary Tales   TV-G  Suitable for all ages.                 35
# 997  Growing Up Wild      G                     NaN                 35
#
#      release year  user rating score  user rating size
# 996          2013                NaN                82
# 997          2016               80.0                80

# %%
import seaborn as sns
data = sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data = sns.load_dataset('tips', engine='python')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df = pd.read_csv('data-netflix.csv', skipfooter = 2, engine='python') # encoding = 'utf-8'

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df = pd.read_csv('data-netflix.csv', nrows = 100)
df.shape
# Out:
# (100, 7)

# %%
df = pd.read_excel('data-netflix.xlsx', sheet_name = 0)
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# ### Reading Json data into Pandas

# %%
movies_json = pd.read_json('data-netflix.json')
movies_json.head()
# Out:
#                                   title rating  \
# 0                          White Chicks  PG-13
# 1                   Lucky Number Slevin      R
# 10                     Once Upon a Time  TV-PG
# 100  The Life Aquatic with Steve Zissou      R
# 101                 Lucky Number Slevin      R
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 10   Parental guidance suggested. May not be suitab...                 70
# 100  language, some drug use, violence and partial ...                100
# 101  strong violence, sexual content and adult lang...                100
#
#      release year  user rating score  user rating size
# 0            2004               82.0                80
# 1            2006                NaN                82
# 10           2016               98.0                80
# ...

# %% [markdown]
# #### pickle: 객체로 db 저장

# %%
df = pd.read_pickle('data-netflix.p')
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
import sqlite3
conn = sqlite3.connect('data-netflix.sqlite')
df = pd.read_sql_query('SELECT * FROM data-netflix;', conn)
# Out:
# -----------------------------------------------------------------------
# OperationalError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1399             else:
# -> 1400                 cur.execute(*args)
#    1401             return cur
#
# OperationalError: near "-": syntax error
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                         Traceback (most recent call last)
# <ipython-input-82-97cb39e0d862> in <module>()
#       1 import sqlite3
#       2 conn = sqlite3.connect('data-netflix.sqlite')
# ----> 3 df = pd.read_sql_query('SELECT * FROM data-netflix;', conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
# ...

# %% [markdown]
# dataframe 객체생성방법: 3가지
# 1. class instance (read 함수)
# 2. class method
# 3. From

# %%
df = pd.read_csv('data-netflix.csv')
df.to_html('a.html')

# %%
df['title'].head()
## Series로 반환하므로 표 없음
# Out:
# 0             White Chicks
# 1      Lucky Number Slevin
# 2           Grey's Anatomy
# 3             Prison Break
# 4    How I Met Your Mother
# Name: title, dtype: object

# %%
df[['title']].head()
## dataFrame으로 반환
# Out:
#                    title
# 0           White Chicks
# 1    Lucky Number Slevin
# 2         Grey's Anatomy
# 3           Prison Break
# 4  How I Met Your Mother

# %%
df[['title','rating']].head()
# Out:
#                    title rating
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG

# %% [markdown]
# ## 180726 (추출)

# %%
df.loc[1:3, 'rating']
# label base
# Out:
# 1        R
# 2    TV-14
# 3    TV-14
# Name: rating, dtype: object

# %%
df.iloc[1:3,1] #가져올 column의 index
# list baes (sequence indexing)
# Out:
# 1        R
# 2    TV-14
# Name: rating, dtype: object

# %% [markdown]
# dictionary
# attribute
# loc
# iloc
# at
# iat
