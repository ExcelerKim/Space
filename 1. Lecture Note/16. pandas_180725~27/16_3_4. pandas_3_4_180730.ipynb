# %%
import pandas as pd

# %%
df = pd.read_csv('pew.txt')

# %%
df.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
pew_long = pd.melt(df, id_vars='religion')

# %%
pew_long = pd.melt(df, id_vars='religion',var_name='income',value_name='count')
pew_long.head()
# Out:
#              religion income  count
# 0            Agnostic  <$10k     27
# 1             Atheist  <$10k     12
# 2            Buddhist  <$10k     27
# 3            Catholic  <$10k    418
# 4  Don’t know/refused  <$10k     15

# %% [markdown]
# ### pandas data type
# #### numereic: int64, float64, bull
# #### string: object, category(statistics)
# #### time, date

# %%
ebola = pd.read_csv(
    'E:/Workspace/Bigdata_Edu/1. Lecture Note/16. pandas_180725~27/data_4/country_timeseries.csv')

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola_long = pd.melt(ebola,id_vars=['Date','Day'])

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
##split
'Cases_Guinea'.split('_')
# Out:
# ['Cases', 'Guinea']

# %%
var_split = ebola_long['variable'].str.split('_')

# %%
type(var_split)
# Out:
# pandas.core.series.Series

# %%
var_split.head()
# Out:
# 0    [Cases, Guinea]
# 1    [Cases, Guinea]
# 2    [Cases, Guinea]
# 3    [Cases, Guinea]
# 4    [Cases, Guinea]
# Name: variable, dtype: object

# %%
status_value = var_split[0]

# %%
weather = pd.read_csv(
    'E:/Workspace/Bigdata_Edu/1. Lecture Note/16. pandas_180725~27/data_1/weather.txt',sep='\t')

# %%
weather.shape
# Out:
# (22, 35)

# %%
del weather['id']

# %%
weather_long = pd.melt(weather,id_vars=['year','month','element'])

# %%
wt_group = weather_long.groupby(['year','month','element','variable']).mean()
wt_group.head()
# Out:
#                              value
# year month element variable
# 2010 1     TMAX    d1          NaN
#                    d10         NaN
#                    d11         NaN
#                    d12         NaN
#                    d13         NaN

# %%
bb = pd.read_csv('E:/Workspace/Bigdata_Edu/1. Lecture Note/16. pandas_180725~27/data_1/billboard.csv')

# %%
bb.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
bb_long = pd.melt(bb,
                  id_vars=['year','artist.inverted','track','time','genre','date.entered','date.peaked'],
                  var_name='week',
                  value_name='rating')

# %%
bb_long.pivot_table(columns=['genre','artist.inverted','track'],
                    index=['year','week'],
                    values='rating')
# Out:
# genre                                        2000-08-19       Country  \
# artist.inverted 98?,Give Me Just One Night (Una Noche)" Adkins, Trace
# track                                              3:24          More
# year week
# 2000 x10th.week                                     7.0          83.0
#      x11th.week                                    22.0          92.0
#      x12th.week                                    29.0           NaN
#      x13th.week                                    36.0           NaN
#      x14th.week                                    47.0           NaN
#      x15th.week                                    67.0           NaN
#      x16th.week                                    66.0           NaN
#      x17th.week                                    84.0           NaN
#      x18th.week                                    93.0           NaN
#      x19th.week                                    94.0           NaN
# ...
