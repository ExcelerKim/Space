# %%
import pandas as pd

# %%
df = pd.read_csv('data-zillow.csv')
# df = pd.read_table('data-zillow.csv',sep=',') #구분자 인식

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df.tail()
# Out:
#              Date  RegionID         RegionName State     Metro      County  \
# 10825  2017-05-31     26077            Nehalem    OR       NaN   Tillamook
# 10826  2017-05-31     24105  Clear Lake Shores    TX   Houston   Galveston
# 10827  2017-05-31    737788    Lebanon Borough    NJ  New York   Hunterdon
# 10828  2017-05-31    182023            Henrico    VA  Richmond     Henrico
# 10829  2017-05-31     51793     East Hampstead    NH    Boston  Rockingham
#
#        SizeRank    Zhvi
# 10825     10825  392200
# 10826     10826  191900
# 10827     10827  231100
# 10828     10828  230800
# 10829     10829  296400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.sample()
# Out:
#             Date  RegionID RegionName State Metro  County  SizeRank    Zhvi
# 4409  2017-05-31     20811     Tipton    IN   NaN  Tipton      4409  102300

# %%
regions = df.loc[:2,:]
regions
# Out:
#          Date  RegionID   RegionName State                           Metro  \
# 0  2017-05-31      6181     New York    NY                        New York
# 1  2017-05-31     12447  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426      Chicago    IL                         Chicago
#
#         County  SizeRank    Zhvi
# 0       Queens         0  672400
# 1  Los Angeles         1  629900
# 2         Cook         2  222700

# %%
regions = df.loc[2:3,'Date':'State']
regions
# Out:
#          Date  RegionID    RegionName State
# 2  2017-05-31     17426       Chicago    IL
# 3  2017-05-31     13271  Philadelphia    PA

# %%
df.loc[df.State == 'PA', :'RegionName']
# Out:
#              Date  RegionID             RegionName
# 3      2017-05-31     13271           Philadelphia
# 54     2017-05-31     26529             Pittsburgh
# 230    2017-05-31     16726              Allentown
# 301    2017-05-31     11335                   Erie
# 327    2017-05-31     41629           West Chester
# 355    2017-05-31    397569     Bethlehem Township
# 395    2017-05-31      6696                Reading
# 470    2017-05-31     20398               Scranton
# 478    2017-05-31     17008              Bethlehem
# 604    2017-05-31    397184          York Township
# 664    2017-05-31    398816              Lancaster
# 733    2017-05-31     30424               Bensalem
# 789    2017-05-31    397360     Millcreek Township
# 793    2017-05-31    397013   Upper Darby Township
# 845    2017-05-31     39416              Levittown
# 857    2017-05-31     11817             Harrisburg
# 937    2017-05-31    398631     Hempfield Township
# ...

# %%
df.describe()
# Out:
#             RegionID      SizeRank          Zhvi
# count   10830.000000  10830.000000  1.083000e+04
# mean    84344.818837   5414.500000  2.503076e+05
# std    125679.686534   3126.496042  2.565582e+05
# min      3301.000000      0.000000  3.740000e+04
# 25%     19346.250000   2707.250000  1.269000e+05
# 50%     35444.500000   5414.500000  1.818000e+05
# 75%     52608.250000   8121.750000  2.823500e+05
# max    737791.000000  10829.000000  6.343800e+06

# %%
df.kurt()
# Out:
# RegionID     2.291461
# SizeRank    -1.200000
# Zhvi        82.042387
# dtype: float64

# %%
df.count()
# Out:
# Date          10830
# RegionID      10830
# RegionName    10830
# State         10830
# Metro         10256
# County        10830
# SizeRank      10830
# Zhvi          10830
# dtype: int64

# %%
df.corr()
# Out:
#           RegionID  SizeRank      Zhvi
# RegionID  1.000000  0.052025 -0.032184
# SizeRank  0.052025  1.000000 -0.115621
# Zhvi     -0.032184 -0.115621  1.000000

# %%
df.cov()
# Out:
#               RegionID      SizeRank          Zhvi
# RegionID  1.579538e+10  2.044245e+07 -1.037760e+09
# SizeRank  2.044245e+07  9.774978e+06 -9.274275e+07
# Zhvi     -1.037760e+09 -9.274275e+07  6.582212e+10

# %%
df.loc[:2,'RegionName':'SizeRank']
# Out:
#     RegionName State                           Metro       County  SizeRank
# 0     New York    NY                        New York       Queens         0
# 1  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles         1
# 2      Chicago    IL                         Chicago         Cook         2

# %%
# %timeit df.loc[:2,'RegionName':'SizeRank']
# Out:
# 306 µs ± 6.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.iloc[:2,2:7]
# Out:
#     RegionName State                           Metro       County  SizeRank
# 0     New York    NY                        New York       Queens         0
# 1  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles         1

# %%
# %timeit df.iloc[:2,2:7]
# Out:
# 276 µs ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.loc[1:7,'Metro':'County']
# Out:
#                             Metro        County
# 1  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2                         Chicago          Cook
# 3                    Philadelphia  Philadelphia
# 4                         Phoenix      Maricopa
# 5                       Las Vegas         Clark
# 6                       San Diego     San Diego
# 7               Dallas-Fort Worth        Dallas

# %%
df['newCategory']='x'
df.iloc[:10,-2:]
# Out:
#      Zhvi newCategory
# 0  672400           x
# 1  629900           x
# 2  222700           x
# 3  137300           x
# 4  211300           x
# 5  216500           x
# 6  572100           x
# 7  164700           x
# 8  877400           x
# 9  152300           x

# %%
del df['newCategory']
df.iloc[:10,-2:]
# Out:
#    SizeRank    Zhvi
# 0         0  672400
# 1         1  629900
# 2         2  222700
# 3         3  137300
# 4         4  211300
# 5         5  216500
# 6         6  572100
# 7         7  164700
# 8         8  877400
# 9         9  152300

# %%
df.loc[1,'Metro']
# Out:
# 'Los Angeles-Long Beach-Anaheim'

# %%
# %timeit df.loc[1,'Metro']
# Out:
# 6.76 µs ± 184 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.iloc[1,4]
# Out:
# 'Los Angeles-Long Beach-Anaheim'

# %%
# %timeit df.iloc[1,4]
# Out:
# 7.6 µs ± 203 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.at[1,'Metro']
# Out:
# 'Los Angeles-Long Beach-Anaheim'

# %%
# %timeit df.at[1,'Metro']
# Out:
# 4.5 µs ± 170 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.iat[1,4]
# Out:
# 'Los Angeles-Long Beach-Anaheim'

# %%
# %timeit df.iat[1,4]
# Out:
# 4.63 µs ± 177 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.iloc[[1,3],4]
# Out:
# 1    Los Angeles-Long Beach-Anaheim
# 3                      Philadelphia
# Name: Metro, dtype: object

# %%
df.iloc[1:4,4]
# Out:
# 1    Los Angeles-Long Beach-Anaheim
# 2                           Chicago
# 3                      Philadelphia
# Name: Metro, dtype: object

# %%
df.iloc[201:205, 3:6]
# Out:
#     State                           Metro         County
# 201    OH                          Canton          Stark
# 202    LA                     New Orleans      Jefferson
# 203    CA       Santa Maria-Santa Barbara  Santa Barbara
# 204    CA  Los Angeles-Long Beach-Anaheim    Los Angeles

# %%
df.loc[201:205,'State':'County']
# Out:
#     State                           Metro         County
# 201    OH                          Canton          Stark
# 202    LA                     New Orleans      Jefferson
# 203    CA       Santa Maria-Santa Barbara  Santa Barbara
# 204    CA  Los Angeles-Long Beach-Anaheim    Los Angeles
# 205    CA  Los Angeles-Long Beach-Anaheim         Orange

# %%
df.loc[df.State=='CA',['Metro','County']].head()
# Out:
#                              Metro         County
# 1   Los Angeles-Long Beach-Anaheim    Los Angeles
# 6                        San Diego      San Diego
# 8                         San Jose    Santa Clara
# 10                   San Francisco  San Francisco
# 29                          Fresno         Fresno

# %%
df.loc[df['State']=='CA',['Metro','County']].head()
# Out:
#                              Metro         County
# 1   Los Angeles-Long Beach-Anaheim    Los Angeles
# 6                        San Diego      San Diego
# 8                         San Jose    Santa Clara
# 10                   San Francisco  San Francisco
# 29                          Fresno         Fresno

# %%
df.loc[df.Metro=='New York','County'].head()
# Out:
# 0           Queens
# 63           Essex
# 72          Hudson
# 138    Westchester
# 176        Passaic
# Name: County, dtype: object

# %% [markdown]
# #### 열(column) 추출: dict/attribute/loc/iloc/filter
# #### 행(index) 추출: loc/iloc
# #### 셀 추출: loc/iloc/at/iat

# %%
df.iloc[0]
# Out:
# Date          2017-05-31
# RegionID            6181
# RegionName      New York
# State                 NY
# Metro           New York
# County            Queens
# SizeRank               0
# Zhvi              672400
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Date          2017-05-31
# RegionID            6181
# RegionName      New York
# State                 NY
# Metro           New York
# County            Queens
# SizeRank               0
# Zhvi              672400
# Name: 0, dtype: object

# %%
df.sort_values(['State','SizeRank','RegionID'],ascending=[True,True,False]).head()
# Out:
#             Date  RegionID  RegionName State      Metro                County  \
# 57    2017-05-31     23482   Anchorage    AK  Anchorage             Anchorage
# 842   2017-05-31     38465   Fairbanks    AK  Fairbanks  Fairbanks North Star
# 1793  2017-05-31     36906      Palmer    AK  Anchorage     Matanuska Susitna
# 1830  2017-05-31     29910  North Pole    AK  Fairbanks  Fairbanks North Star
# 1974  2017-05-31      5365      Juneau    AK     Juneau                Juneau
#
#       SizeRank    Zhvi
# 57          57  293900
# 842        842  221000
# 1793      1793  247800
# 1830      1830  213100
# 1974      1974  323100

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df.sort_values(['State','SizeRank','RegionID'],ascending=[True,True,False], inplace=True)

# %%
df.head()
# Out:
#             Date  RegionID  RegionName State      Metro                County  \
# 57    2017-05-31     23482   Anchorage    AK  Anchorage             Anchorage
# 842   2017-05-31     38465   Fairbanks    AK  Fairbanks  Fairbanks North Star
# 1793  2017-05-31     36906      Palmer    AK  Anchorage     Matanuska Susitna
# 1830  2017-05-31     29910  North Pole    AK  Fairbanks  Fairbanks North Star
# 1974  2017-05-31      5365      Juneau    AK     Juneau                Juneau
#
#       SizeRank    Zhvi
# 57          57  293900
# 842        842  221000
# 1793      1793  247800
# 1830      1830  213100
# 1974      1974  323100

# %%
df.sort_values('RegionID',inplace=True)

# %%
df.head()
# Out:
#             Date  RegionID   RegionName State                     Metro  \
# 3043  2017-05-31      3301     Aberdeen    NC  Pinehurst-Southern Pines
# 4159  2017-05-31      3304      Absecon    NJ             Atlantic City
# 4986  2017-05-31      3305     Accokeek    MD                Washington
# 1762  2017-05-31      3310          Ada    OK                       Ada
# 3116  2017-05-31      3312  Adairsville    GA                   Atlanta
#
#               County  SizeRank    Zhvi
# 3043           Moore      3043  163900
# 4159        Atlantic      4159  164400
# 4986  Prince Georges      4986  360400
# 1762        Pontotoc      1762   99800
# 3116          Bartow      3116  124300

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index        Date  RegionID   RegionName State                     Metro  \
# 0   3043  2017-05-31      3301     Aberdeen    NC  Pinehurst-Southern Pines
# 1   4159  2017-05-31      3304      Absecon    NJ             Atlantic City
# 2   4986  2017-05-31      3305     Accokeek    MD                Washington
# 3   1762  2017-05-31      3310          Ada    OK                       Ada
# 4   3116  2017-05-31      3312  Adairsville    GA                   Atlanta
#
#            County  SizeRank    Zhvi
# 0           Moore      3043  163900
# 1        Atlantic      4159  164400
# 2  Prince Georges      4986  360400
# 3        Pontotoc      1762   99800
# 4          Bartow      3116  124300

# %%
df.reset_index(drop=True)
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
df.sort_values('RegionID').head()
# Out:
#    index        Date  RegionID   RegionName State                     Metro  \
# 0   3043  2017-05-31      3301     Aberdeen    NC  Pinehurst-Southern Pines
# 1   4159  2017-05-31      3304      Absecon    NJ             Atlantic City
# 2   4986  2017-05-31      3305     Accokeek    MD                Washington
# 3   1762  2017-05-31      3310          Ada    OK                       Ada
# 4   3116  2017-05-31      3312  Adairsville    GA                   Atlanta
#
#            County  SizeRank    Zhvi
# 0           Moore      3043  163900
# 1        Atlantic      4159  164400
# 2  Prince Georges      4986  360400
# 3        Pontotoc      1762   99800
# 4          Bartow      3116  124300

# %%
df.reset_index(drop=True)
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
df.filter(items = ['State','Metro']).head()
# Out:
#   State                     Metro
# 0    NC  Pinehurst-Southern Pines
# 1    NJ             Atlantic City
# 2    MD                Washington
# 3    OK                       Ada
# 4    GA                   Atlanta

# %%
filtered_data = df.filter(regex='^Region',axis=1)
filtered_data.head()
# Out:
#    RegionID   RegionName
# 0      3301     Aberdeen
# 1      3304      Absecon
# 2      3305     Accokeek
# 3      3310          Ada
# 4      3312  Adairsville

# %%
df.loc[df['Zhvi']>= 1000000].head()
# Out:
#      index        Date  RegionID    RegionName State                  Metro  \
# 30    7720  2017-05-31      3509   Bal Harbour    FL  Miami-Fort Lauderdale
# 71   10205  2017-05-31      3734   Boca Grande    FL             Fort Myers
# 144   7385  2017-05-31      4145    Clyde Hill    WA                Seattle
# 173    757  2017-05-31      4281     Cupertino    CA               San Jose
# 376   3225  2017-05-31      5415  Key Biscayne    FL  Miami-Fort Lauderdale
#
#           County  SizeRank     Zhvi
# 30    Miami-Dade      7720  1043000
# 71           Lee     10205  1382300
# 144         King      7385  2425000
# 173  Santa Clara       757  1847800
# 376   Miami-Dade      3225  1165900

# %%
df[df.Zhvi>=1000000].head()
# Out:
#      index        Date  RegionID    RegionName State                  Metro  \
# 30    7720  2017-05-31      3509   Bal Harbour    FL  Miami-Fort Lauderdale
# 71   10205  2017-05-31      3734   Boca Grande    FL             Fort Myers
# 144   7385  2017-05-31      4145    Clyde Hill    WA                Seattle
# 173    757  2017-05-31      4281     Cupertino    CA               San Jose
# 376   3225  2017-05-31      5415  Key Biscayne    FL  Miami-Fort Lauderdale
#
#           County  SizeRank     Zhvi
# 30    Miami-Dade      7720  1043000
# 71           Lee     10205  1382300
# 144         King      7385  2425000
# 173  Santa Clara       757  1847800
# 376   Miami-Dade      3225  1165900

# %%
filtered_data = df.filter(like='Region',axis=1)
filtered_data.head()
# Out:
#    RegionID   RegionName
# 0      3301     Aberdeen
# 1      3304      Absecon
# 2      3305     Accokeek
# 3      3310          Ada
# 4      3312  Adairsville

# %%
df[(df['Zhvi']>1000000) & (df['State'] =='NY')].sort_values('index')
# Out:
#       index        Date  RegionID              RegionName State     Metro  \
# 2557   1132  2017-05-31     18375              Great Neck    NY  New York
# 8450   2405  2017-05-31     54333               Scarsdale    NY  New York
# 7357   2619  2017-05-31     47495                     Rye    NY  New York
# 3748   3032  2017-05-31     25725               Manhasset    NY  New York
# 2646   3064  2017-05-31     18955               Larchmont    NY  New York
# 2572   3474  2017-05-31     18478                Harrison    NY  New York
# 1886   3904  2017-05-31     13937             Southampton    NY  New York
# 8175   4700  2017-05-31     52907                Lawrence    NY  New York
# 6180   5682  2017-05-31     40053             North Hills    NY  New York
# 8332   6386  2017-05-31     53705            Old Westbury    NY  New York
# 1694   6661  2017-05-31     12894              Muttontown    NY  New York
# 2466   6736  2017-05-31     17874              East Hills    NY  New York
# ...

# %% [markdown]
# ### 행 필터링 Row Index filtering

# %%
1 in [1,2,3]
# Out:
# True

# %%
df['State'].isin(['DC','PA'])
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 10800    False
# 10801    False
# 10802    False
# 10803    False
# 10804    False
# 10805    False
# 10806    False
# 10807    False
# 10808    False
# 10809    False
# 10810    False
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# ...

# %%
df.isin({'State':['CA'],'Metro':['Sanfransisco']})
# Out:
#         Date  RegionID  RegionName  State  Metro  County  SizeRank   Zhvi
# 0      False     False       False  False  False   False     False  False
# 1      False     False       False   True  False   False     False  False
# 2      False     False       False  False  False   False     False  False
# 3      False     False       False  False  False   False     False  False
# 4      False     False       False  False  False   False     False  False
# 5      False     False       False  False  False   False     False  False
# 6      False     False       False   True  False   False     False  False
# 7      False     False       False  False  False   False     False  False
# 8      False     False       False   True  False   False     False  False
# 9      False     False       False  False  False   False     False  False
# 10     False     False       False   True  False   False     False  False
# 11     False     False       False  False  False   False     False  False
# ...

# %%
df[df.isin({'State':['CA'],'Metro':['Sanfransisco']})]
# Out:
#       Date  RegionID RegionName State Metro County  SizeRank  Zhvi
# 0      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 1      NaN       NaN        NaN    CA   NaN    NaN       NaN   NaN
# 2      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 3      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 4      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 5      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 6      NaN       NaN        NaN    CA   NaN    NaN       NaN   NaN
# 7      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 8      NaN       NaN        NaN    CA   NaN    NaN       NaN   NaN
# 9      NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 10     NaN       NaN        NaN    CA   NaN    NaN       NaN   NaN
# 11     NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# 12     NaN       NaN        NaN   NaN   NaN    NaN       NaN   NaN
# ...

# %%
# %timeit(df.loc[1:3,'Date'])
# Out:
# 92.2 µs ± 1.79 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit(df.loc[1:3,['Date']])
# Out:
# 773 µs ± 10.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.RegionName.str.capitalize().head()
# df['RegionName'].str.capitalize()
# upper, lower
# Out:
# 0        New york
# 1     Los angeles
# 2         Chicago
# 3    Philadelphia
# 4         Phoenix
# Name: RegionName, dtype: object

# %%
df['RegionName'] = df.RegionName.str.upper()
df.RegionName.head()
# Out:
# 0        NEW YORK
# 1     LOS ANGELES
# 2         CHICAGO
# 3    PHILADELPHIA
# 4         PHOENIX
# Name: RegionName, dtype: object

# %%
df.RegionName.str.replace('YORK','york!').head()
# Out:
# 0       NEW york!
# 1     LOS ANGELES
# 2         CHICAGO
# 3    PHILADELPHIA
# 4         PHOENIX
# Name: RegionName, dtype: object

# %%
df.RegionName.map(lambda x: x+'-map').head()
# Out:
# 0        NEW YORK-map
# 1     LOS ANGELES-map
# 2         CHICAGO-map
# 3    PHILADELPHIA-map
# 4         PHOENIX-map
# Name: RegionName, dtype: object

# %%
df['Length'] = df.County.str.len()

# %%
df.iloc[:5,-2:]
# Out:
#      Zhvi  Length
# 0  672400       6
# 1  629900      11
# 2  222700       4
# 3  137300      12
# 4  211300       8

# %%
df.RegionName.str.replace(" ","").head()
# Out:
# 0         NEWYORK
# 1      LOSANGELES
# 2         CHICAGO
# 3    PHILADELPHIA
# 4         PHOENIX
# Name: RegionName, dtype: object
